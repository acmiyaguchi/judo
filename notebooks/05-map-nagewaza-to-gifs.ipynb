# %%
import pandas as pd
from pathlib import Path

gifs = sorted(Path("../data/clips-masked-gif").glob("*.gif"))
data = []
for gif in gifs:
    category, num, name, _ = gif.stem.split("_")
    data.append([category, int(num), name, str(gif.name)])
info_df = pd.DataFrame(data, columns=["category", "num", "name", "path"])
info_df = info_df[["category", "num", "name"]]
info_df.to_csv("../data/gif-info.csv", index=False)
info_df
# Out:
#              category  num                  name
# 0           ashi-waza    0         de-ashi-harai
# 1           ashi-waza    1           hiza-guruma
# 2           ashi-waza    2  sasae-tsurikomi-ashi
# 3           ashi-waza    3           o-soto-gari
# 4           ashi-waza    4           o-uchi-gari
# ..                ...  ...                   ...
# 106  yoko-sutemi-waza   11    uchi-mata-makikomi
# 107  yoko-sutemi-waza   12        harai-makikomi
# 108  yoko-sutemi-waza   13      ko-uchi-makikomi
# 109  yoko-sutemi-waza   14           kani-basami
# 110  yoko-sutemi-waza   15           kawazu-gake
#
# [111 rows x 3 columns]

# %%
info_df = pd.read_csv("../data/waza-info-translation.csv")
info_df.head()
# Out:
#     category  num                  name                       translated_name
# 0  ashi-waza    0         de-ashi-harai                    Forward Foot Sweep
# 1  ashi-waza    1           hiza-guruma                            Knee Wheel
# 2  ashi-waza    2  sasae-tsurikomi-ashi  Propping-Lifting Pulling Ankle Throw
# 3  ashi-waza    3           o-soto-gari                   Major Outer Reaping
# 4  ashi-waza    4           o-uchi-gari                   Major Inner Reaping

# %%
nagewaza_df = pd.read_csv("../data/nagewaza.csv")
nagewaza_df.head()
# Out:
#               technique            group  group_index
# 0           Deashi Hari  Dai Ikkyo (1st)            1
# 1           Hiza Guruma  Dai Ikkyo (1st)            2
# 2  Sasae Tsurikomi Ashi  Dai Ikkyo (1st)            3
# 3             Uki Goshi  Dai Ikkyo (1st)            4
# 4            Osoto Gari  Dai Ikkyo (1st)            5

# %%
# let's encode the group names as integers, based on the order in which they appear in the list
mapping = {v: k + 1 for k, v in enumerate(nagewaza_df.group.unique())}
mapping["Unclassified"] = 0
mapping
nagewaza_df["group_id"] = nagewaza_df.group.map(mapping)
nagewaza_df
# Out:
#                technique               group  group_index  group_id
# 0            Deashi Hari     Dai Ikkyo (1st)            1         1
# 1            Hiza Guruma     Dai Ikkyo (1st)            2         1
# 2   Sasae Tsurikomi Ashi     Dai Ikkyo (1st)            3         1
# 3              Uki Goshi     Dai Ikkyo (1st)            4         1
# 4             Osoto Gari     Dai Ikkyo (1st)            5         1
# 5                O Goshi     Dai Ikkyo (1st)            6         1
# 6             Ouchi Gari     Dai Ikkyo (1st)            7         1
# 7              Seoi Nage     Dai Ikkyo (1st)            8         1
# 8            Kosoto Gari     Dai Nikyo (2nd)            1         2
# 9            Kouchi Gari     Dai Nikyo (2nd)            2         2
# 10          Koshi Guruma     Dai Nikyo (2nd)            3         2
# 11       Tsurikomi Goshi     Dai Nikyo (2nd)            4         2
# 12       Okuriashi Harai     Dai Nikyo (2nd)            5         2
# 13            Tai Otoshi     Dai Nikyo (2nd)            6         2
# 14           Harai Goshi     Dai Nikyo (2nd)            7         2
# 15             Uchi Mata     Dai Nikyo (2nd)            8         2
# 16           Kosoto Gake        Sankyo (3rd)            1         3
# 17           Tsuri Goshi        Sankyo (3rd)            2         3
# 18           Yoko Otoshi        Sankyo (3rd)            3         3
# 19           Ashi Guruma        Sankyo (3rd)            4         3
# 20            Hane Goshi        Sankyo (3rd)            5         3
# 21  Harai Tsurikomi Ashi        Sankyo (3rd)            6         3
# 22            Tomoe Nage        Sankyo (3rd)            7         3
# 23           Kata Guruma        Sankyo (3rd)            8         3
# 24           Sumi Gaeshi        Yonkyo (4th)            1         4
# 25           Tani Otoshi        Yonkyo (4th)            2         4
# 26         Hane Makikomi        Yonkyo (4th)            3         4
# 27            Sukui Nage        Yonkyo (4th)            4         4
# 28          Utsuri Goshi        Yonkyo (4th)            5         4
# 29              O Guruma        Yonkyo (4th)            6         4
# 30         Soto Makikomi        Yonkyo (4th)            7         4
# 31            Uki Otoshi        Yonkyo (4th)            8         4
# 32          Osoto Guruma         Gokyo (5th)            1         5
# 33              Uki Waza         Gokyo (5th)            2         5
# 34           Yoko Wakare         Gokyo (5th)            3         5
# 35           Yoko Guruma         Gokyo (5th)            4         5
# 36          Ushiro Goshi         Gokyo (5th)            5         5
# 37              Ura Nage         Gokyo (5th)            6         5
# 38           Sumi Otoshi         Gokyo (5th)            7         5
# 39             Yoko Gake         Gokyo (5th)            8         5
# 40           Morote Gari  Shinmeisho No Waza            1         6
# 41        Kuchiki Taoshi  Shinmeisho No Waza            2         6
# 42         Kibisu Gaeshi  Shinmeisho No Waza            3         6
# 43     Uchi Mata Sukashi  Shinmeisho No Waza            4         6
# 44              Daki Age  Shinmeisho No Waza            5         6
# 45        Tsubame Gaeshi  Shinmeisho No Waza            6         6
# 46         Kouchi Gaeshi  Shinmeisho No Waza            7         6
# 47          Ouchi Gaeshi  Shinmeisho No Waza            8         6
# 48          Osoto Gaeshi  Shinmeisho No Waza            9         6
# 49    Harai Goshi Gaeshi  Shinmeisho No Waza           10         6
# 50      Uchi Mata Gaeshi  Shinmeisho No Waza           11         6
# 51     Hane Goshi Gaeshi  Shinmeisho No Waza           12         6
# 52           Kani Basami  Shinmeisho No Waza           13         6
# 53        Osoto Makikomi  Shinmeisho No Waza           14         6
# 54           Kawazu Gake  Shinmeisho No Waza           15         6
# 55        Harai Makikomi  Shinmeisho No Waza           16         6
# 56    Uchi Mata Makikomi  Shinmeisho No Waza           17         6
# 57  Sode Tsurikomi Goshi  Shinmeisho No Waza           18         6
# 58        Ippon Seoinage  Shinmeisho No Waza           19         6

# %%
import editdistance


def closest_item(item, items):
    return min(items, key=lambda x: editdistance.eval(item, x))


closest_item("Deashi Hari", info_df.name)
# Out:
# 'de-ashi-harai'

# %%
nagewaza_df["technique_id"] = nagewaza_df.technique.apply(
    lambda x: closest_item(x, info_df.name)
)
nagewaza_df
# Out:
#                technique               group  group_index  group_id  \
# 0            Deashi Hari     Dai Ikkyo (1st)            1         1
# 1            Hiza Guruma     Dai Ikkyo (1st)            2         1
# 2   Sasae Tsurikomi Ashi     Dai Ikkyo (1st)            3         1
# 3              Uki Goshi     Dai Ikkyo (1st)            4         1
# 4             Osoto Gari     Dai Ikkyo (1st)            5         1
# 5                O Goshi     Dai Ikkyo (1st)            6         1
# 6             Ouchi Gari     Dai Ikkyo (1st)            7         1
# 6            o-uchi-gari
# 7              seoi-nage
# 8            o-soto-gari
# 9            o-uchi-gari
# 10          koshi-guruma
# 11       tsurikomi-goshi
# 12      okuri-ashi-harai
# 13            tai-otoshi
# 14           harai-goshi
# 15             uchi-mata
# 16          ko-soto-gake
# 17           tsuri-goshi
# 18           yoko-otoshi
# 19           ashi-guruma
# 20            hane-goshi
# 21  harai-tsurikomi-ashi
# 22            tomoe-nage
# 23           kata-guruma
# 24           sumi-gaeshi
# 25           tani-otoshi
# 26         hane-makikomi
# 27            sukui-nage
# 28           tsuri-goshi
# 29              o-guruma
# 30         soto-makikomi
# 31            uki-otoshi
# 32         o-soto-guruma
# 33              uki-waza
# 34           yoko-wakare
# 35           yoko-guruma
# 36          ushiro-goshi
# 37              ura-nage
# 38           sumi-otoshi
# 39             yoko-gake
# 40           morote-gari
# 41        kuchiki-taoshi
# 42         kibisu-gaeshi
# 43     uchi-mata-sukashi
# 44              ura-nage
# 45        tsubame-gaeshi
# 46         o-uchi-gaeshi
# 47         o-uchi-gaeshi
# 48         o-soto-gaeshi
# 49    harai-goshi-gaeshi
# 50      uchi-mata-gaeshi
# 51     hane-goshi-gaeshi
# 52           kani-basami
# 53         soto-makikomi
# 54           kawazu-gake
# 55        harai-makikomi
# 56    uchi-mata-makikomi
# 57  sode-tsurikomi-goshi
# 58       ippon-seoi-nage

# %%
df = info_df.merge(nagewaza_df, left_on="name", right_on="technique_id", how="left")
df = df[
    ["category", "num", "name", "translated_name", "group", "group_index", "group_id"]
]
df["group_index"] = df["group_index"].fillna(0).astype(int)
df["group_id"] = df["group_id"].fillna(0).astype(int)
df["group"] = df["group"].fillna("Uncategorized")
df
# Out:
#              category  num                  name  \
# 0           ashi-waza    0         de-ashi-harai
# 1           ashi-waza    1           hiza-guruma
# 2           ashi-waza    2  sasae-tsurikomi-ashi
# 3           ashi-waza    3           o-soto-gari
# 4           ashi-waza    3           o-soto-gari
# ..                ...  ...                   ...
# 112  yoko-sutemi-waza   11    uchi-mata-makikomi
# 113  yoko-sutemi-waza   12        harai-makikomi
# 114  yoko-sutemi-waza   13      ko-uchi-makikomi
# 115  yoko-sutemi-waza   14           kani-basami
# 116  yoko-sutemi-waza   15           kawazu-gake
#
#                           translated_name               group  group_index  \
# 0                      Forward Foot Sweep     Dai Ikkyo (1st)            1
# 1                              Knee Wheel     Dai Ikkyo (1st)            2
# 2    Propping-Lifting Pulling Ankle Throw     Dai Ikkyo (1st)            3
# 3                     Major Outer Reaping     Dai Ikkyo (1st)            5
# 4                     Major Outer Reaping     Dai Nikyo (2nd)            1
# ..                                    ...                 ...          ...
# 112                Inner Thigh Wraparound  Shinmeisho No Waza           17
# 113                   Sweeping Wraparound  Shinmeisho No Waza           16
# 114                Minor Inner Wraparound       Uncategorized            0
# 115                    Crab Claw Scissors  Shinmeisho No Waza           13
# 116                  One-leg Entanglement  Shinmeisho No Waza           15
#
#      group_id
# 0           1
# 1           1
# 2           1
# 3           1
# 4           2
# ..        ...
# 112         6
# 113         6
# 114         0
# 115         6
# 116         6
#
# [117 rows x 7 columns]

# %%
df.to_csv("../data/meta/waza.csv", index=False)
df.to_json("../data/meta/waza.json", orient="records")
